# %% [markdown]
# # 데이터 분석 실습 파일
# 주의사항
# - 구글 코랩 상에서 실행할 경우 본 파일(digital_humanity_datafile)은 "analysis.py" 파일과 함께 "drive/MyDrive/"에 위치해 있어야 합니다.

# %% [markdown]
# ### 구글 코랩 상에서 실행할 경우 1 / 컴퓨터에서 실행할 경우 2를 참고

# %% [markdown]
# ### 1. 구글 코랩 상에서 실행할 시 먼저 아래 셀을 실행하시기 바랍니다. 2는 실행하실 필요없습니다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/digital_humanity

# !pip install udkanbun
# !pip install openai
# !pip install konlpy

# %% [markdown]
# ### 2. 컴퓨터의 Visual Studio Code 혹은 Jupyter Notebook으로 실행할 시 아래 셀을 실행하시기 바랍니다.
# - 1을 실행할 경우 오류가 발생합니다.

# %%
# !pip install numpy
# !pip install pandas
# !pip install udkanbun
# !pip install openai
# !pip install konlpy
# !pip install flask
# !pip install openai
# !pip install tqdm
# !pip install re
# !pip install nltk
# !pip install transformers
# !pip install torch
# !pip install matplotlib
# !pip install datetime
# !pip install plotly
# !pip install collections
# !pip install itertools
# !pip install gensim
# !pip install sklearn
# !pip install scipy
# !pip install operator
# !pip install networkx
# !pip install seaborn
# !pip install xml

# %% [markdown]
# ## 데이터 분석
# - 한문버전의 경우 1 / 한글버전의 경우 2

# %%
from analysis import * ## 데이터 분석에 필요한 함수 가져오기
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-chinese and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at monologg/kobert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### 1. 한문버전

# %% [markdown]
# 데이터 API로 불러오기

# %%
고전원문_ck = 0
한국문집총간_ck = 1
한국고전총간_ck = 0
### 고전원문을 원하시면 고전원문_ck = 1 나머지는 0 / 나머지 항목 마찬가지 (반드시 한 가지만 1이어야 합니다.)
keyword = "사단칠정" ### 쌍따옴표 안에 원하는 키워드를 입력한 후 실행합니다.

# %%
data = total_data(keyword, 고전원문_ck, 한국문집총간_ck, 한국고전총간_ck)
# Out:
# 100%|██████████| 1/1 [00:09<00:00,  9.16s/it]

# %%
data[1].head() ## 데이터를 잘 불러왔는지 확인합니다.
# Out:
#          서명      Sentence Raw   간행년  \
# 0  산당집(山堂集)     [其論四端七情心性理氣之]  1685
# 1  면앙집(俛仰集)  [四端七情之辨, 無論四端七情]  1829
# 2  면앙집(俛仰集)        [所敎四端七情之說]  1829
# 3  일재집(一齋集)          [四端七情之論]  1673
# 4  퇴계집(退溪集)          [其論四端七情]  1843
#
#                                                  URL
# 0  https://db.itkc.or.kr/dir/item?itemId=JT#dir/n...
# 1  https://db.itkc.or.kr/dir/item?itemId=JT#dir/n...
# 2  https://db.itkc.or.kr/dir/item?itemId=JT#dir/n...
# 3  https://db.itkc.or.kr/dir/item?itemId=JT#dir/n...
# 4  https://db.itkc.or.kr/dir/item?itemId=JT#dir/n...

# %%
time_series_data(data[0]) ### 키워드에 대한 시간에 따른 평가를 진행합니다. (주의 : 데이터의 용량이 클 경우 시간이 10분 이상 소요될 수 있습니다.)
# Out:
#                      sentiment
# 간행년
# 1595-01-01 00:00:00   0.568054
# 1629-01-01 00:00:00   0.563412
# 1636-01-01 00:00:00   0.596299
# 1640-01-01 00:00:00   0.590183
# 1643-01-01 00:00:00   0.550719
# ...                        ...
# 1937-01-01 00:00:00   0.593737
# 1938-01-01 00:00:00   0.615634
# 1939-01-01 00:00:00   0.576973
# 1948-01-01 00:00:00   0.570144
# 1960-01-01 00:00:00   0.555834
#
# [147 rows x 1 columns]

# %%
generate_wordcloud_image(data[0]) ### Word Cloud를 생성합니다.
# Out:
# 100%|██████████| 804/804 [01:20<00:00,  9.99it/s]

# %%
frequancy = frequency_analysis(data[0]) ### 빈도분석을 실시합니다.
# Out:
# ...
# 100%|██████████| 804/804 [01:22<00:00,  9.69it/s]

# %%
correl = cosine_relate(frequancy[0], frequancy[1]) ### 빈출 단어 간 연관성을 분석합니다.

# %%
network_analysis(correl) ### 단어의 중요도를 수치화 및 시각화하여 보여줍니다.

# %% [markdown]
# ### 사용자 요청 텍스트 분석 : 한문용

# %%
text = """    """
### 분석하고자 하는 텍스트를 """ """ 안에 입력해주세요.

# %%
df_text = text_frequently(text) ### 빈도 분석을 실시합니다.
# Out:
# ...
# 100%|██████████| 1/1 [00:00<00:00, 12.03it/s]

# %%
text_correlate(df_text) ### 빈출 단어 간 연관성을 분석합니다.
# Out:
#       words  tfidf_score
# 0     不/adv      0.19518
# 1    極/noun      0.19518
# 2    陰/noun      0.19518
# 3    太/verb      0.19518
# 4    思/verb      0.19518
# 5    陽/noun      0.19518
# 6    後/noun      0.09759
# 7   孟/propn      0.09759
# 8    流/verb      0.09759
# 9    形/noun      0.09759
# 10   中/noun      0.09759
# 11   行/verb      0.09759

# %% [markdown]
# ### 2. 한글 버전

# %% [markdown]
# API를 통해 데이터 가져오기

# %%
조선왕조실록_ck = 0
신역_조선왕조실록_ck = 0
승정원일기_ck = 0
일성록_ck = 0
고전번역서_ck = 0
### 조선왕조실록을 원하시면 조선왕조실록_ck = 1 나머지는 0 / 나머지 항목 마찬가지 (반드시 한 가지만 1이어야 합니다.)
keyword = "예송" ### 쌍따옴표 안에 원하시는 키워드를 입력합니다.

# %%
data_kr = total_data_kr(keyword, 고전번역서_ck, 조선왕조실록_ck, 신역_조선왕조실록_ck, 승정원일기_ck, 일성록_ck)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]

# %%
time_series_data_kr(data_kr[0]) ### 키워드에 대한 시간에 따른 평가를 보여줍니다. (주의 : 데이터의 용량이 클 경우 시간이 10분 이상 소요될 수 있습니다.)

# %%
generate_wordcloud_image_kr(data_kr[0]) ### word cloud를 생성합니다.
# Out:
#  43%|████▎     | 52/120 [00:03<00:02, 24.17it/s]
# Error processing sentence: )과 부수찬 윤광운(尹光運)을 풀어 주도록 하는 일은 탑전 하교(榻前下敎)를 내라.” 하였다. 신하들이 차례로 물러 나갔다. | 대의나(大矣乃)로 …… 읽었는가 835년(흥덕왕10) 기사에 대한 사평(史評) 중 “庾信之於<em class="hl1">新羅</em>功亦大矣...  ... 然周公有大勳勞 而成王賜魯重祭 猶以爲非 況追封爲王 以紊君臣之名分乎”의 ‘大矣’와 ‘然’의 연결 관계에 대한 토를 가리킨다. 《東國通鑑 <em class="hl1">新羅</em> 興德王 10年 2月》 위장하니(爲將󰑞) 토 838년(희강왕3) 12월 기사 중 “又遣驍勇閻長...  ...張弁鄭年駱金張建榮李順行等六人統兵爲將 軍容甚盛”의 ‘爲將’과 그 뒷부분의 연결 관계에 대한 토를 가리킨다. 《東國通鑑 <em class="hl1">新羅</em> 僖康王 3年 12月》 우(禹)는 …… 걱정하였고 원문은 ‘禹憂九年之水’이다. 9년 동안의 홍수는 요(堯) 임금. Error: 'utf-8' codec can't decode byte 0xed in position 0: invalid continuation byte
# 100%|██████████| 120/120 [00:03<00:00, 34.74it/s]

# %%
frequency_kr = frequency_analysis_kr(data_kr[0]) ### 빈도 분석을 실시합니다.
# Out:
#  36%|███▌      | 43/120 [00:01<00:01, 38.87it/s]
# Error processing sentence: )과 부수찬 윤광운(尹光運)을 풀어 주도록 하는 일은 탑전 하교(榻前下敎)를 내라.” 하였다. 신하들이 차례로 물러 나갔다. | 대의나(大矣乃)로 …… 읽었는가 835년(흥덕왕10) 기사에 대한 사평(史評) 중 “庾信之於<em class="hl1">新羅</em>功亦大矣...  ... 然周公有大勳勞 而成王賜魯重祭 猶以爲非 況追封爲王 以紊君臣之名分乎”의 ‘大矣’와 ‘然’의 연결 관계에 대한 토를 가리킨다. 《東國通鑑 <em class="hl1">新羅</em> 興德王 10年 2月》 위장하니(爲將󰑞) 토 838년(희강왕3) 12월 기사 중 “又遣驍勇閻長...  ...張弁鄭年駱金張建榮李順行等六人統兵爲將 軍容甚盛”의 ‘爲將’과 그 뒷부분의 연결 관계에 대한 토를 가리킨다. 《東國通鑑 <em class="hl1">新羅</em> 僖康王 3年 12月》 우(禹)는 …… 걱정하였고 원문은 ‘禹憂九年之水’이다. 9년 동안의 홍수는 요(堯) 임금. Error: 'utf-8' codec can't decode byte 0xed in position 0: invalid continuation byte
# 100%|██████████| 120/120 [00:02<00:00, 50.21it/s]

# %%
correl = cosine_relate_kr(frequency_kr[0], frequency_kr[1]) ### 빈출 단어 간 연관성을 분석합니다.

# %%
network_analysis_kr(correl) ### 단어의 중요도를 수치화 및 시각화하여 제시합니다.

# %% [markdown]
# ### 사용자 요청 텍스트 분석 (한글)

# %%
text_kr = """  """
### 분석하고자 하는 텍스트를 """ """ 안에 입력해주세요.

# %%
df_text_kr = text_frequently_kr(text_kr) ### 빈도 분석을 실시합니다.
# Out:
# ...
# 100%|██████████| 1/1 [00:00<00:00, 43.47it/s]

# %%
text_correlate_kr(df_text_kr) ### 빈출 단어 간 연관성을 분석합니다.
# Out:
#        words  tfidf_score
# 0     조선/nnp     0.234888
# 1     국가/nng     0.176166
# 2   장렬왕후/nnp     0.176166
# 3     정치/nng     0.176166
# 4       되/vv     0.176166
# 5     왕조/nnp     0.176166
# 6       하/vv     0.176166
# 7     사회/nng     0.117444
# 8     모후/nng     0.117444
# 9       입/vv     0.117444
# 10   정치사/nnp     0.058722
# 11    연결/nng     0.058722
# 12    전제/nnp     0.058722
# 13    환국/nnp     0.058722
# 14   분기점/nng     0.058722
